# %% [markdown]
# <a href="https://colab.research.google.com/github/camilo520/ProcesamientoImagen/blob/master/Laboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#importar librerias

import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/Laboratorio imagen/'
os.chdir(path)
# !pwd
# %matplotlib inline
# Out:
# /content/drive/My Drive/Laboratorio imagen

# %%
def displayGray3(a, b, c, title1="Original", title2="Edited", title3="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(131),plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132),plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(133),plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
    
def displayGray2(a, b, title1="Original", title2="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(121),plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
    
def displayColor3(a, b, c, title1="Original", title2="Edited", title3="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(131),plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132),plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(133),plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.show()    
    
    
def displayColor2(a, b, title1="Original", title2="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(121),plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()        
    
def readRGB(imgPath):
    img=cv2.imread(imgPath)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img
  
def displayGray5(a, b, c, d, e, title1="Original", title2="Edited", title3="Edited", title4="Edited", title5="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(151),plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(152),plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(153),plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(154),plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.subplot(155),plt.imshow(e, cmap='gray'), plt.title(title5)
    plt.xticks([]), plt.yticks([])
    plt.show()  
    
def displayGray4(a, b, c, d, title1="Original", title2="Edited", title3="Edited", title4="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(141),plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(142),plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(143),plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(144),plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()      
    
def display4(a, b, c, d, title1="Original", title2="Edited", title3="Edited", title4="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(141),plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(142),plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(143),plt.imshow(c, cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(144),plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()    
    
def Threshold(img, thres):
    #img=cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    rows, columns = img.shape
    img2=np.zeros((rows, columns), dtype=np.uint8)
    
    T=thres
    
    for x in range(0,rows):
        for y in range(0, columns):
            r=img[x][y]
            if T<=r:
                img2[x][y]=255
            else:
                img2[x][y]=0
    displayGray2(img, img2)
    return img2

# %% [markdown]
# # Punto **1**

# %%
img=cv2.imread('furi.jpg',0)
x_sobel=cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)

y_sobel=cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

xy_sobel = x_sobel+y_sobel

displayGray4(img, x_sobel, y_sobel, xy_sobel, "Original", "Vertical", "Horizontal", "Diagonal")

# %%
img=cv2.imread('furi2.jpg',0)
x_sobel=cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)

y_sobel=cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

xy_sobel = x_sobel+y_sobel

displayGray4(img, x_sobel, y_sobel, xy_sobel, "Original", "Vertical", "Horizontal", "Diagonal")

# %%
img=cv2.imread('furi3.jpg',0)
x_sobel=cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)

y_sobel=cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

xy_sobel = x_sobel+y_sobel

displayGray4(img, x_sobel, y_sobel, xy_sobel, "Original", "Vertical", "Horizontal", "Diagonal")

# %% [markdown]
# # **Punto 2**

# %%
img=cv2.imread("cabeza.png", 0)
median = cv2.medianBlur(img,3)

displayGray2(img, median)

# %%
img=cv2.imread("sal.png", 0)
median = cv2.medianBlur(img,3)

displayGray2(img, median)

# %%
img=cv2.imread("sal2.png", 0)
median = cv2.medianBlur(img,3)
median2=cv2.medianBlur(median,3)

displayGray2(img, median2)

# %%
img=cv2.imread("sal3.png", 0)
median = cv2.medianBlur(img,13)
median2 = cv2.medianBlur(median,13)
median3 = cv2.medianBlur(median2,13)
#median4 = cv2.medianBlur(median3,13)

#displayGray2(img, median4)
displayGray2(img, median3)

# %%
img=cv2.imread("sal4.png", 0)
median = cv2.medianBlur(img,5)
median2 = cv2.medianBlur(median,5)
median3 = cv2.medianBlur(median2,3)
bilateral=cv2.bilateralFilter(median3,9,150,150)

displayGray2(img, bilateral)

# %%
img=cv2.imread("sal5.png", 0)
median = cv2.medianBlur(img,7)
median2 = cv2.medianBlur(median,3)
median3 = cv2.medianBlur(median2,3)
displayGray2(img, median3)

# %% [markdown]
# # Punto **3**

# %%
img=cv2.imread('furi.jpg', 0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.zeros((fils,cols,2), np.uint8)
mask[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=1

fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
imgfinal=img_back*img

displayGray5(img, img_back, fshift_mask_mag, magnitude_spectrum, imgfinal,"Original", "Filtro pasa bajo", "Mascara", "Espectro", "Con imagen original")

#---------------------------------

centfils, centcols=fils/2, cols/2

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=0

fshift=dft_shift*mask2
fshift_mask_mag2=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back2=cv2.idft(f_shift)
img_back2=cv2.magnitude(img_back2[:,:,0], img_back2[:,:,1])
imgfinal2=img_back2*img

displayGray5(img, img_back2, fshift_mask_mag2, magnitude_spectrum, imgfinal2,"Original", "Filtro pasa alto", "Mascara", "Espectro", "Con imagen original")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in log

# %%
img=cv2.imread('furi2.jpg', 0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.zeros((fils,cols,2), np.uint8)
mask[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=1

fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
imgfinal=img_back*img

displayGray5(img, img_back, fshift_mask_mag, magnitude_spectrum, imgfinal, "Original", "Filtro pasa bajo", "Mascara", "Espectro", "Con imagen original")

#-------------------------------------------

centfils, centcols=fils/2, cols/2

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=0

fshift=dft_shift*mask2
fshift_mask_mag2=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back2=cv2.idft(f_shift)
img_back2=cv2.magnitude(img_back2[:,:,0], img_back2[:,:,1])
imgfinal2=img_back2*img

displayGray5(img, img_back2, fshift_mask_mag2, magnitude_spectrum, imgfinal2, "Original", "Filtro pasa bajo", "Mascara", "Espectro", "Con imagen original")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in log

# %%
img=cv2.imread('furi3.jpg', 0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.zeros((fils,cols,2), np.uint8)
mask[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=1

fshift=dft_shift*mask
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
imgfinal=img_back*img

displayGray5(img, img_back, fshift_mask_mag, magnitude_spectrum, imgfinal, "Original", "Filtro pasa bajo", "Mascara", "Espectro", "Con imagen original")

#--------------------------------------

centfils, centcols=fils/2, cols/2

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)-10:np.int32(centfils)+10, np.int32(centcols)-10:np.int32(centcols)+10]=0

fshift=dft_shift*mask2
fshift_mask_mag2=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back2=cv2.idft(f_shift)
img_back2=cv2.magnitude(img_back2[:,:,0], img_back2[:,:,1])
imgfinal2=img_back2*img

displayGray5(img, img_back2, fshift_mask_mag2, magnitude_spectrum, imgfinal2, "Original", "Filtro pasa alto", "Mascara", "Espectro", "Con imagen original")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# # Punto **4**

# %%
img=cv2.imread('lena.png',0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.ones((fils,cols,2), np.uint8)
mask[np.int32(centfils)-60:np.int32(centfils)-30, np.int32(centcols)-218:np.int32(centcols)+260]=0

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)+30:np.int32(centfils)+60, np.int32(centcols)-218:np.int32(centcols)+260]=0

mask3=np.ones((fils,cols,2), np.uint8)
mask3[np.int32(centfils)+180:np.int32(centfils)+210, np.int32(centcols)-218:np.int32(centcols)+260]=0

mask4=np.ones((fils,cols,2), np.uint8)
mask4[np.int32(centfils)-195:np.int32(centfils)+200, np.int32(centcols)-70:np.int32(centcols)-50]=0

mask5=np.ones((fils,cols,2), np.uint8)
mask5[np.int32(centfils)-195:np.int32(centfils)+200, np.int32(centcols)+60:np.int32(centcols)+80]=0

mask6=np.ones((fils,cols,2), np.uint8)
mask6[np.int32(centfils)-195:np.int32(centfils)+200, np.int32(centcols)-190:np.int32(centcols)-170]=0

maskFinal=mask*mask2*mask3*mask4*mask5*mask6

fshift=dft_shift*maskFinal
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img, img_back, fshift_mask_mag, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log

# %%
img=cv2.imread('ball.png',0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.ones((fils,cols,2), np.uint8)
mask[np.int32(centfils)-60:np.int32(centfils)-40, np.int32(centcols)-40:np.int32(centcols)+80]=0

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)+30:np.int32(centfils)+60, np.int32(centcols)-40:np.int32(centcols)+80]=0

maskFinal=mask*mask2

fshift=dft_shift*maskFinal
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img, img_back, fshift_mask_mag, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log

# %%
img=cv2.imread('nasa.png',0)
img_flotante=np.float32(img)
dft=cv2.dft(img_flotante, flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols=fils/2, cols/2

mask=np.ones((fils,cols,2), np.uint8)
mask[np.int32(centfils)-230:np.int32(centfils)+250, np.int32(centcols)-310:np.int32(centcols)-70]=0

mask2=np.ones((fils,cols,2), np.uint8)
mask2[np.int32(centfils)-230:np.int32(centfils)+250, np.int32(centcols)+100:np.int32(centcols)+400]=0

mask3=np.ones((fils,cols,2), np.uint8)
mask3[np.int32(centfils)+60:np.int32(centfils)+235, np.int32(centcols)-70:np.int32(centcols)+100]=0

mask4=np.ones((fils,cols,2), np.uint8)
mask4[np.int32(centfils)-225:np.int32(centfils)-100, np.int32(centcols)-80:np.int32(centcols)+100]=0

maskFinal=mask*mask2*mask3*mask4

fshift=dft_shift*maskFinal
fshift_mask_mag=2000*np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_shift)
img_back=cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray4(img, img_back, fshift_mask_mag, magnitude_spectrum)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
