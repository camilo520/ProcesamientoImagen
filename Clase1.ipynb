# %% [markdown]
# <a href="https://colab.research.google.com/github/camilo520/ProcesamientoImagen/blob/master/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Prueba Imagen**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Importar Librerias**

# %%
#importar librerias

import numpy as np
import matplotlib.pyplot as plt
import cv2

#importar imagenes
# %matplotlib inline

# %% [markdown]
# # **Leer y Mostrar Imagen**

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/ProcesamientoImagen/ciencia-del-universo-1530540262286.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x674 at 0x7F7225A156D8>

# %% [markdown]
# # **Cargar y Visualizar con matplotlib**

# %%
#leeer una imagen
#principio of least 
img_BGR=cv2.imread('/content/drive/My Drive/ProcesamientoImagen/ciencia-del-universo-1530540262286.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# # **Clase 2**
# # Cambiar ruta

# %%
# !pwd
# !ls
#%cd ../
# %cd /content/drive/My Drive/ProcesamientoImagen/
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('ciencia-del-universo-1530540262286.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(500),int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/ProcesamientoImagen
# ciencia-del-universo-1530540262286.jpg
# /content/drive/My Drive/ProcesamientoImagen
# /content/drive/My Drive/ProcesamientoImagen
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F24FB87FC50>

# %% [markdown]
# # **Cambiar ruta opcion 2**
# # **codigo python**

# %%
import os
path='/content/drive/My Drive/ProcesamientoImagen/'
os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('ciencia-del-universo-1530540262286.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/ProcesamientoImagen
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F24FB87F828>

# %% [markdown]
# # **Cambiar tamaño de la imagen**

# %%
#expandir
print(img.shape)
res = cv2.resize(img, None, fx=10, fy=10, interpolation=cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 300, 3)
# (3000, 3000, 3)

# %%
print(img.shape)
res = cv2.resize(img, None, fx=.1, fy=.1, interpolation=cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 300, 3)
# (30, 30, 3)

# %% [markdown]
# # Remover numeracion de los ejes

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Cambiar de BGR a RGB**

# %%
#pasar la imagen a rgb
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Convertir a escala de grises**

# %%
#pasar la imagen a gris
img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Usar metodos para mostrar las imagenes**

# %%
#Display two images
def display(a, b, title1="Original", title2="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(121),plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show
    
#Display one image
def display_one(a,title1="Original"):
    plt.imshow(a), plt.title(title1)
    plt.show()

display_one(img_BGR)

# %%
display(img_RGB, img_BGR)

# %%
def display4(a, b, c, d, title1="Original", title2="Edited", title3="Edited", title4="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(221),plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222),plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223),plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224),plt.imshow(d, cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display4(img_RGB, img_BGR, img_GRAY, img_GRAY)
